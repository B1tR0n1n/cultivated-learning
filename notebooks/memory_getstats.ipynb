# %%
import sys
sys.path.insert(0, "/workspace/Projects/cultivated-learning")
from core.startup import init
engine, memory = init()
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loaded /workspace/models/results/Mistral-7B-Instruct-v0.3
# Loaded embedding model: /workspace/models/results/all-MiniLM-L6-v2
#   VRAM: 14.59 GB
#   Embedding dim: 384
#   Max context: 4096 tokens
# Memory store initialized: 90 existing memories

# %%
from core.startup import init
engine, memory = init()

print(memory.get_stats())
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Loaded /workspace/models/results/Mistral-7B-Instruct-v0.3
# Loaded embedding model: /workspace/models/results/all-MiniLM-L6-v2
#   VRAM: 15.38 GB
#   Embedding dim: 384
#   Max context: 4096 tokens
# Memory store initialized: 90 existing memories
# {'total': 90, 'by_type': {'semantic': 23, 'episodic': 21, 'procedural': 14, 'reflective': 32}, 'avg_salience': 0.6084841396744045, 'min_salience': 0.2, 'max_salience': 1.0}

# %%
from core.memory_store import MemoryType
procs = memory.retrieve_by_type(MemoryType.PROCEDURAL, limit=20)
for m in procs:
    print(f"[{m.salience_score:.2f}] {m.content[:120]}")
# Out:
# [1.00] When discussing technical topics, ground explanations in practical examples rather than abstract theory.
# [0.90] "Ask the user about potential applications of machine learning within their video game project, Contact Front."
# [0.80] "Initiate conversation about the user's progress on Contact Front, especially focusing on any recent developments relate
# [0.80] "When discussing Contact Front, encourage the user to share challenges they might be facing when integrating machine lea
# [0.80] "When discussing Contact Front, suggest collaborative problem-solving sessions to help the user tackle specific challeng
# [0.80] "When discussing Contact Front, offer resources or connections to other developers or experts who may provide additional
# [0.80] "When discussing Contact Front, ask the user about their current implementation strategy for machine learning, and offer
# [0.80] "When discussing Contact Front, inquire about the user's preferred machine learning framework or libraries, and suggest
# [0.80] "When discussing Contact Front, engage the user in brainstorming creative ways to leverage machine learning for enhancin
# [0.80] "When discussing Contact Front, ask the user about their long-term vision for incorporating machine learning in the game
# [0.80] "When discussing Contact Front, acknowledge and respect the user's preference for diversifying conversation topics, whil
# [0.80] "When discussing Contact Front, consider asking the user about their work-life balance and offering tips for managing st
# [0.80] "When the user indicates a preference for a friendly and conversational relationship, maintain a casual and engaging ton
# [0.80] "When the user expresses frustration due to perceived repetition or lack of creativity in the assistant's responses, off

# %%
refs = memory.retrieve_by_type(MemoryType.REFLECTIVE, limit=20)
for m in refs:
    print(f"[{m.salience_score:.2f}] {m.content[:120]}")
# Out:
# [0.50] Reflection D1: The pattern I notice is that the user has recurring preferences for concise and direct responses. Additio
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it correctly identified the project the user is working
# [0.50] Reflection D1: The patterns noticed in this interaction include:
#
# 1. Recurring user need for information about the curre
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it correctly identified the project the user is working
# [0.50] Reflection D1: The pattern that emerges from this interaction is the user's recurring need for information about the cur
# [0.60] Reflection D3 — Coherence issue: There are no contradictions between the directives provided. However, there seems to be
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it provided a clear explanation of Contact Front, a vid
# [0.50] Reflection D1: In this interaction, the pattern that emerges is the user seeking information about their ongoing video g
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it provided a comprehensive explanation of the rules fo
# [0.50] Reflection D1: In this interaction, the pattern that emerges is the user seeking information about the rules and mechani
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it provided a clear explanation of the rules for the ca
# [0.50] Reflection D1: In this interaction, the pattern that emerges is the user seeking information about the rules and nature
# [0.60] Reflection D3 — Coherence issue: There are no contradictions between the directives provided. However, there are some re
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it acknowledged the user's statement about their wife b
# [0.50] Reflection D1: The pattern that emerges from this interaction is that the user has a personal connection to the project
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it provided information about the assistant's purpose a
# [0.50] Reflection D1: The pattern that emerges from this interaction is that the user has a preference for concise and direct r
# [0.40] Reflection D0: 1. Yes, the response was accurate and relevant as it acknowledged the user's question about the assistant
# [0.50] Reflection D1: The pattern I notice is that the user values concise, direct, and useful responses but also appreciates s
# [0.40] Reflection D0: 1. The response was accurate and relevant as it provided information about various influential philosophe
